# %% [markdown]
# # Housing Price EDA
#
# ## Objective
# Understand the dataset, clean it, and extract insights about price drivers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset

df = pd.read_csv("C:\Users\ADMIN\OneDriveDocuments/housing_price_eda/data/raw_data.csv")

df.columns = df.columns.str.lower().str.strip()

for col in df.select_dtypes(include=["object", "string"]).columns:
    df[col] = df[col].str.lower().str.strip().str.replace(" ", "_", regex=False)



df.head()

# %%
print("Shape:", df.shape)
df.info()
df.describe()

# %%
# missing values

missing = df.isnull().sum()

missing = missing[missing >0]
missing = missing.sort_values(ascending= False)

missing

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object', 'string']).columns
